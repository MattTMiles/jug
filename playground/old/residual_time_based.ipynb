# %% [markdown]
# # Time-based residuals (JAX)
#
# Minimal notebook that computes Tempo2/PINT-style time-domain residuals using JAX/JIT for the J1909-3744 par/tim pair.

# %%
import sys
from pathlib import Path

import jax
import jax.numpy as jnp
import numpy as np

# Use local PINT checkout to parse par/tim
sys.path.insert(0, str(Path('../PINT/src').resolve()))
from pint import models
from pint.toa import get_TOAs
from pint import residuals as pint_residuals

SECS_PER_DAY = 86400.0

par_path = Path('/home/mattm/projects/MPTA/partim/production/fifth_pass/J1909-3744.par')
tim_path = Path('/home/mattm/projects/MPTA/partim/production/fifth_pass/J1909-3744.tim')

model_pint = models.get_model(str(par_path), allow_tcb=True)
toas = get_TOAs(str(tim_path), model=model_pint)
print(f"Loaded {len(toas)} TOAs")

# PINT residuals for comparison
pint_res = pint_residuals.Residuals(toas, model_pint)
pint_time_us = pint_res.time_resids.to('us').value
print(f"PINT RMS (us): {np.sqrt(np.mean(pint_time_us**2)):.6f}")
print(f"PINT first 5 (us): {pint_time_us[:5]}")
# Out:
# /home/mattm/soft/PINT/src/pint/models/timing_model.py:403: UserWarning: PINT does not support 'DILATEFREQ Y'
#   warn("PINT does not support 'DILATEFREQ Y'")
# /home/mattm/soft/PINT/src/pint/models/timing_model.py:406: UserWarning: PINT only supports 'TIMEEPH FB90'
#   warn("PINT only supports 'TIMEEPH FB90'")
# 2025-11-27 02:48:42.119 | WARNING  | pint.models.timing_model:validate:429 - PINT does not support 'UNITS TCB' internally. Reading this par file nevertheless because the `allow_tcb` option was given. This `TimingModel` object should not be used for anything except converting to TDB.
# /home/mattm/soft/PINT/src/pint/models/model_builder.py:220: UserWarning: Unrecognized parfile line 'EPHVER 5'
#   warnings.warn(f"Unrecognized parfile line '{p_line}'", UserWarning)
# /home/mattm/soft/PINT/src/pint/models/model_builder.py:220: UserWarning: Unrecognized parfile line 'DM_SERIES TAYLOR'
#   warnings.warn(f"Unrecognized parfile line '{p_line}'", UserWarning)
# 2025-11-27 02:48:42.120 | WARNING  | pint.models.tcb_conversion:convert_tcb_tdb:133 - Converting this timing model from TCB to TDB. Please note that the TCB to TDB conversion is only approximate and the resulting timing model should be re-fit to get reliable results.
# 2025-11-27 02:48:42.135 | DEBUG    | pint.toa:get_TOAs:195 - Using EPHEM = DE440 from the given model
# 2025-11-27 02:48:42.135 | DEBUG    | pint.toa:get_TOAs:211 - Using CLOCK = BIPM2024 from the given model
# 2025-11-27 02:48:42.135 | DEBUG    | pint.toa:get_TOAs:232 - Using PLANET_SHAPIRO = True from the given model
# 2025-11-27 02:48:43.135 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-11-27 02:48:43.145 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-11-27 02:48:43.332 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-11-27 02:48:43.332 | DEBUG    | pint.observatory:_load_gps_clock:108 - Loading global GPS clock file
# 2025-11-27 02:48:43.334 | DEBUG    | pint.observatory.clock_file:__init__:812 - Global clock file gps2utc.clk saving kwargs={'bogus_last_correction': False, 'valid_beyond_ends': False}
# 2025-11-27 02:48:43.335 | DEBUG    | pint.observatory.clock_file:read_tempo2_clock_file:463 - Loading TEMPO2-format observatory clock correction file gps2utc.clk (/home/mattm/.astropy/cache/download/url/d3c81b5766f4bfb84e65504c8a453085/contents) with bogus_last_correction=False
# 2025-11-27 02:48:43.343 | INFO     | pint.observatory:find_clock_file:973 - Using global clock file for gps2utc.clk with bogus_last_correction=False
# 2025-11-27 02:48:43.344 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2024) clock correction (~27 us)
# 2025-11-27 02:48:43.344 | INFO     | pint.observatory:_load_bipm_clock:119 - Loading BIPM clock version bipm2024
# 2025-11-27 02:48:43.344 | DEBUG    | pint.observatory.clock_file:__init__:812 - Global clock file tai2tt_bipm2024.clk saving kwargs={'bogus_last_correction': False, 'valid_beyond_ends': False}
# 2025-11-27 02:48:43.345 | DEBUG    | pint.observatory.clock_file:read_tempo2_clock_file:463 - Loading TEMPO2-format observatory clock correction file tai2tt_bipm2024.clk (/home/mattm/.astropy/cache/download/url/f67a80f7bab29eb56fb072d16bd604a6/contents) with bogus_last_correction=False
# 2025-11-27 02:48:43.347 | INFO     | pint.observatory:find_clock_file:973 - Using global clock file for tai2tt_bipm2024.clk with bogus_last_correction=False
# 2025-11-27 02:48:43.348 | DEBUG    | pint.observatory.clock_file:__init__:812 - Global clock file mk2utc_observatory.clk saving kwargs={'bogus_last_correction': False, 'valid_beyond_ends': False}
# 2025-11-27 02:48:43.350 | DEBUG    | pint.observatory.clock_file:read_tempo2_clock_file:463 - Loading TEMPO2-format observatory clock correction file mk2utc_observatory.clk (/home/mattm/.astropy/cache/download/url/a7a637f1a00db405d01d4f99e5150bbf/contents) with bogus_last_correction=False
# 2025-11-27 02:48:43.499 | INFO     | pint.observatory:find_clock_file:973 - Using global clock file for mk2utc_observatory.clk with bogus_last_correction=False
# 2025-11-27 02:48:43.499 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='meerkat'.
# 2025-11-27 02:48:44.565 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-11-27 02:48:44.566 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-11-27 02:48:44.958 | DEBUG    | pint.toa:get_TOAs:310 - Planet PosVels will be calculated.
# 2025-11-27 02:48:44.959 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-11-27 02:48:45.020 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-11-27 02:48:45.540 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.17983945e+11  8.26974645e+10  3.58410549e+10] m
# 2025-11-27 02:48:45.541 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-11-27 02:48:45.544 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-11-27 02:48:45.546 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-11-27 02:48:45.548 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-11-27 02:48:45.551 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-11-27 02:48:45.552 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-11-27 02:48:45.554 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-11-27 02:48:45.559 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# Loaded 10408 TOAs
# 2025-11-27 02:48:45.952 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:101 - Creating and dealing with the single TZR_toa for absolute phase
# 2025-11-27 02:48:45.953 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-11-27 02:48:45.953 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-11-27 02:48:45.954 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-11-27 02:48:45.955 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-11-27 02:48:45.955 | INFO     | pint.observatory:_load_bipm_clock:119 - Loading BIPM clock version bipm2023
# 2025-11-27 02:48:45.956 | DEBUG    | pint.observatory.clock_file:__init__:812 - Global clock file tai2tt_bipm2023.clk saving kwargs={'bogus_last_correction': False, 'valid_beyond_ends': False}
# 2025-11-27 02:48:45.957 | DEBUG    | pint.observatory.clock_file:read_tempo2_clock_file:463 - Loading TEMPO2-format observatory clock correction file tai2tt_bipm2023.clk (/home/mattm/.astropy/cache/download/url/d0c6b0f6a57e39d4a167cd2aa08ad383/contents) with bogus_last_correction=False
# 2025-11-27 02:48:45.959 | INFO     | pint.observatory:find_clock_file:973 - Using global clock file for tai2tt_bipm2023.clk with bogus_last_correction=False
# 2025-11-27 02:48:45.960 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='meerkat'.
# 2025-11-27 02:48:45.961 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-11-27 02:48:45.961 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-11-27 02:48:45.962 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-11-27 02:48:45.962 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-11-27 02:48:45.964 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.42093793e+11 -4.68168107e+10 -2.02653443e+10] m
# 2025-11-27 02:48:45.965 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-11-27 02:48:45.965 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-11-27 02:48:45.965 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-11-27 02:48:45.966 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-11-27 02:48:45.966 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-11-27 02:48:45.966 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-11-27 02:48:45.966 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-11-27 02:48:45.967 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-11-27 02:48:45.967 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:122 - Done with TZR_toa
# PINT RMS (us): 0.820289
# PINT first 5 (us): [-1.95642748 -0.93402091 -0.98108717 -1.19099971 -0.12538321]

# %%
# Extract barycentric TDB times and a simple spin model
bary_mjd = np.array([t.value for t in toas.get_mjds(high_precision=True)], dtype=np.float64)
freq_mhz = np.array(toas.table['freq'].to('MHz').value, dtype=np.float64)

class SpinModel:
    def __init__(self, f0, f1, tref_mjd):
        self.f0 = float(f0)
        self.f1 = float(f1)
        self.tref_mjd = float(tref_mjd)

spin_model = SpinModel(
    f0=model_pint.F0.value,
    f1=getattr(model_pint, 'F1', 0.0).value if hasattr(model_pint, 'F1') else 0.0,
    tref_mjd=model_pint.PEPOCH.value if hasattr(model_pint, 'PEPOCH') else model_pint.POSEPOCH.value,
)
spin_model.__dict__
# Out:
# {'f0': 339.31569191904083,
#  'f1': -1.6147500686892461e-15,
#  'tref_mjd': 59017.9997538705}

# %%
@jax.jit
def residuals_time_domain(t_bary_mjd, model: SpinModel):
    """Tempo2/PINT-style time residuals: frac(phase)/F0 at barycentric time."""
    dt_sec = (t_bary_mjd - model.tref_mjd) * SECS_PER_DAY
    phase = model.f0 * dt_sec + 0.5 * model.f1 * dt_sec**2
    frac_phase = jnp.mod(phase + 0.5, 1.0) - 0.5
    return frac_phase / model.f0

t_bary_jax = jnp.array(bary_mjd)
res_jax_s = residuals_time_domain(t_bary_jax, spin_model)
res_jax_us = np.array(res_jax_s) * 1e6

rms_jax = np.sqrt(np.mean(res_jax_us**2))
corr = np.corrcoef(res_jax_us, pint_time_us)[0, 1]

print(f"JAX time-based RMS (us): {rms_jax:.6f}")
print(f"JAX first 5 (us): {res_jax_us[:5]}")
print(f"Correlation vs PINT: {corr:.6f}")
# Out:
# W1127 02:48:46.311410  869611 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1127 02:48:46.312621  869421 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 10
#       7     return frac_phase / model.f0
#       9 t_bary_jax = jnp.array(bary_mjd)
# ---> 10 res_jax_s = residuals_time_domain(t_bary_jax, spin_model)
#      11 res_jax_us = np.array(res_jax_s) * 1e6
#      13 rms_jax = np.sqrt(np.mean(res_jax_us**2))
#
#     [... skipping hidden 5 frame]
#
# File ~/miniforge3/envs/discotech/lib/python3.12/site-packages/jax/_src/pjit.py:678, in _infer_input_type(fun, dbg_fn, explicit_args)
#     676   dbg = dbg_fn()
#     677   arg_description = f"path {dbg.arg_names[i] if dbg.arg_names is not None else 'unknown'}"  # pytype: disable=name-error
# --> 678   raise TypeError(
#     679     f"Error interpreting argument to {fun} as an abstract array."
#     680     f" The problematic value is of type {type(x)} and was passed to"  # pytype: disable=name-error
#     681     f" the function at {arg_description}.\n"
#     682     "This typically means that a jit-wrapped function was called with a non-array"
#     683     " argument, and this argument was not marked as static using the"
#     684     " static_argnums or static_argnames parameters of jax.jit."
#     685   ) from None
#     686 if config.mutable_array_checks.value:
#     687   check_no_aliased_ref_args(dbg_fn, avals, explicit_args)
#
# TypeError: Error interpreting argument to <function residuals_time_domain at 0x7e3bf3e379c0> as an abstract array. The problematic value is of type <class '__main__.SpinModel'> and was passed to the function at path model.
# This typically means that a jit-wrapped function was called with a non-array argument, and this argument was not marked as static using the static_argnums or static_argnames parameters of jax.jit.
